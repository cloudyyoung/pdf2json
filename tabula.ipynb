# %% [markdown]
# # Acuron

# %%
pdf_path = "test/pdf/dc/form/acuron-label.pdf"

# %%
import tabula

# Read pdf into list of DataFrame
dfs = tabula.read_pdf(pdf_path, pages='all', stream=True)

# %%
len(dfs)
# Out:
# 14

# %%
dfs[3]
# Out:
#         ATRAZINE  GROUP   5  HERBICIDE
# 0  BICYCLOPYRONE  GROUP  27  HERBICIDE
# 1     MESOTRIONE  GROUP  27  HERBICIDE
# 2  S-METOLACHLOR  GROUP  15  HERBICIDE

# %%
pdf_path2 = "test/pdf/dc/form/Blue_Book_2023_web.pdf"

# %% [markdown]
# # Bluebook

# %%
dfs2 = tabula.read_pdf(pdf_path2, pages='all', stream=True)

# %%
len(dfs2)
# Out:
# 704

# %%
dfs2[201]
# Out:
#                         Unnamed: 0  \
# 0                 Tank mix partner
# 1           MCPA (Amine/Ester 600)
# 2                    OcTTain XL***
# 3                         Paradigm
# 4            Paradigm + MCPA ester
# 5             Paradigm + Curtail M
# 6               Pardner/Brotex 240
# 7                      Prestige XC
# 8                              NaN
# 9                        Pixxaro A
# 10           Pixxaro A+ MCPA Ester
# 11                             NaN
# 12            Pixxaro A+ Curtail M
# 13                             NaN
# 14                       Refine SG
# 15                      Refine SG+
# 16          2, 4-D amine/ester 500
# 17                       Stellar A
# 18                         Target*
# 19                  Thumper/Leader
# 20                      Triton C**
# 21                          Trophy
# 22                  In durum wheat
# 23  2,4-D (Amine 600/Ester 700)***
# 24                      Enforcer D
# ...

# %%
pdf_path3 = "test/pdf/dc/form/091234-00154-20200109.pdf"

# %%
dfs3 = tabula.read_pdf(pdf_path3, pages='all')
# Out:
# Got stderr: Jul. 04, 2023 5:19:39 P.M. org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+120 (120) in font BMLPFF+SymbolMT
# Jul. 04, 2023 5:19:39 P.M. org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+131 (131) in font BMMELK+Wingdings-Regular

# %%
len(dfs3)
# Out:
# 146

# %%
dfs3[32]
# Out:
# Empty DataFrame
# Columns: [14 days, 14 days.1]
# Index: []
